# %% [markdown]
# <a href="https://colab.research.google.com/github/climatechangee/student-marks/blob/main/practice_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import seaborn as sns

mydata = pd.read_excel('studentMarks.xlsx')

# %%
mydata.hist(figsize=(20,30))
# Out:
# array([[<AxesSubplot:title={'center':'math score'}>,
#         <AxesSubplot:title={'center':'reading score'}>],
#        [<AxesSubplot:title={'center':'writing score'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
sns.boxplot(x="gender", y="math score", data=mydata)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='math score'>

# %%
pd.crosstab(mydata['reading score'],mydata['gender'] )
# Out:
# gender         female  male
# reading score
# 27                  0     1
# 28                  0     2
# 29                  2     0
# 31                  0     1
# 32                  1     1
# ...               ...   ...
# 96                  3     1
# 97                  1     2
# 98                  2     0
# 99                  1     1
# 100                17     2
#
# [73 rows x 2 columns]

# %%
sns.countplot(x="test preparation course", hue="reading score", data=mydata)
# Out:
# <AxesSubplot:xlabel='test preparation course', ylabel='count'>

# %%
pd.pivot_table(mydata, index=['test preparation course', 'gender'], columns=[ 'math score'], aggfunc=len)
# Out:
#                                lunch                                          \
# math score                       13   23   25   26   28   29   30   31   32
# test preparation course gender
# completed               female   NaN  NaN  NaN  1.0  1.0  NaN  NaN  1.0  NaN
#                         male     NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# none                    female   2.0  1.0  1.0  1.0  1.0  NaN  1.0  1.0  2.0
#                         male     NaN  NaN  NaN  NaN  NaN  1.0  1.0  NaN  NaN
#
#                                      ... writing score                      \
# math score                      33   ...           91   92   93   94   95
# test preparation course gender       ...
# completed               female  1.0  ...           1.0  2.0  NaN  2.0  1.0
#                         male    NaN  ...           2.0  1.0  2.0  3.0  NaN
# none                    female  3.0  ...           2.0  3.0  1.0  NaN  NaN
#                         male    NaN  ...           3.0  1.0  2.0  2.0  1.0
#
#
# math score                      96   97   98   99   100
# test preparation course gender
# completed               female  1.0  NaN  NaN  NaN  3.0
#                         male    1.0  1.0  1.0  1.0  6.0
# none                    female  NaN  NaN  NaN  NaN  NaN
#                         male    1.0  2.0  2.0  2.0  5.0
#
# [4 rows x 385 columns]

# %%
sns.pairplot(mydata)

# %%
mydata['math score'].mean()
# Out:
# 66.396

# %%
sns.distplot(mydata['math score'])

# %%
mydata.hist(by='gender',column = 'test preparation course')
# Out:
# array([<AxesSubplot:title={'center':'female'}>,
#        <AxesSubplot:title={'center':'male'}>], dtype=object)

# %%
mydata.hist(by='gender',column = 'math score', figsize=(20,30))
# Out:
# array([<AxesSubplot:title={'center':'female'}>,
#        <AxesSubplot:title={'center':'male'}>], dtype=object)

# %%
corr = mydata.corr()
sns.heatmap(corr, annot=True)
# Out:
# <AxesSubplot:>
