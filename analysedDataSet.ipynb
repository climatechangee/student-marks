# %% [markdown]
# <a href="https://colab.research.google.com/github/students-mark/student-marks/blob/main/analysedDataSet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mydata = pd.read_excel('studentMarks.xlsx')
mydata.hist(figsize=(20,30))
# Out:
# array([[<Axes: title={'center': 'math score'}>,
#         <Axes: title={'center': 'reading score'}>],
#        [<Axes: title={'center': 'writing score'}>, <Axes: >]],
#       dtype=object)

# %%
sns.boxplot(x="gender", y="math score", data=mydata)
# Out:
# <Axes: xlabel='gender', ylabel='math score'>

# %%
pd.crosstab(mydata['reading score'],mydata['gender'] )
# Out:
# gender         female  male
# reading score
# 27                  0     1
# 28                  0     2
# 29                  2     0
# 31                  0     1
# 32                  1     1
# ...               ...   ...
# 96                  3     1
# 97                  1     2
# 98                  2     0
# 99                  1     1
# 100                17     2
#
# [73 rows x 2 columns]

# %%
sns.countplot(x="test preparation course", hue="reading score", data=mydata)
# Out:
# <Axes: xlabel='test preparation course', ylabel='count'>

# %%
pd.pivot_table(mydata, index=['test preparation course', 'gender'], columns=[ 'math score'], aggfunc=len)
sns.pairplot(mydata)

# %%
mydata['math score'].mean()

# %%
sns.distplot(mydata['math score'])

# %%
mydata.hist(by='gender',column = 'test preparation course')

# %%
mydata.hist(by='gender',column = 'math score', figsize=(20,30))

# %%
corr = mydata.corr()
sns.heatmap(corr, annot=True)
